# %%
import os
# run before import keras to select gpu to use.
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
import glob
import pickle
import numpy as np
from tqdm import tqdm
from natsort import natsorted
from PIL import Image
import pickle
import time

import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5916604684557701640,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 31140001920
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 2802752928403841181
#  physical_device_desc: "device: 0, name: Tesla V100-DGXS-32GB, pci bus id: 0000:0e:00.0, compute capability: 7.0"]

# %%
# !pip install wandb -qqq
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: shogi880 (use `wandb login --relogin` to force relogin)
# True

# %%
def load_pkl(file_name):
    with open(file_name, 'rb') as f:
        return pickle.load(f)
X_train = load_pkl("./X_train.pkl")
X_test = load_pkl("./X_test.pkl")
y_train = load_pkl("./y_train.pkl")
y_test = load_pkl("./y_test.pkl")

# 9228 = 769 * 12. (769 tasks, 12 demos.)
# 888 = 74 * 12. (74 tasks, 12 demos.)
# 125, 125, 3:  image_size
# 768: language_size
assert X_train.shape == (769 * 12, 125, 125, 3)
assert y_train.shape == (769 * 12, 1, 768)
assert X_test.shape == (74 * 12, 125, 125, 3)
assert y_test.shape == (74 * 12, 1, 768)

X_train=X_train.astype("float")/255
X_test=X_test.astype("float")/255

# %%
from wandb.keras import WandbCallback

run = wandb.init(project='Convautoencoder-pretrain_128',
                 config={  # and include hyperparameters and metadata
                     "learning_rate": 0.0001,
                     "epochs": 300,
                     "batch_size": 32,
                     "dim": 256
                 })

config = wandb.config
# Out:
# /root/.pyenv/versions/3.6.8/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
#                 Tracking run with wandb version 0.10.27<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-breeze-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/shogi880/Convautoencoder-pretrain_128" target="_blank">https://wandb.ai/shogi880/Convautoencoder-pretrain_128</a><br/>
#                 Run page: <a href="https://wandb.ai/shogi880/Convautoencoder-pretrain_128/runs/hw7h92f9" target="_blank">https://wandb.ai/shogi880/Convautoencoder-pretrain_128/runs/hw7h92f9</a><br/>
#                 Run data is saved locally in <code>/root/share/tecnets-pytorch/scripts/wandb/run-20210427_141210-hw7h92f9</code><br/><br/>

# %%
# Setting the model.
class ConvolutionalAutoencoder(Model):
    """
    layer = tf.layers.conv2d(layer, 16, 5, 2, 'same')
    layer = tf.contrib.layers.layer_norm(layer, activation_fn="elu")
    """
    def __init__(self, dim):
        super(ConvolutionalAutoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=(125, 125, 3)),
            layers.ZeroPadding2D(padding=(3, 3)),
            layers.Conv2D(32, (4, 4), activation='elu', padding='valid', strides=1),
            layers.Conv2D(32, (4, 4), activation='elu', padding='same', strides=2),
            layers.Conv2D(64, (4, 4), activation='elu', padding='same', strides=2),
            layers.Conv2D(128, (4, 4), activation='elu', padding='same', strides=2),
            layers.Conv2D(256, (4, 4), activation='elu', padding='same', strides=2),
            layers.Flatten(),
            layers.Dense(dim)
            ])
        self.decoder = tf.keras.Sequential([
            layers.Dense(8 * 8 * 256),
            layers.Reshape((8, 8, 256)),
            layers.Conv2DTranspose(128, kernel_size=4, strides=2, activation='elu', padding='same'),
            layers.Conv2DTranspose(64, kernel_size=4, strides=2, activation='elu', padding='same'),
            layers.Conv2DTranspose(32, kernel_size=4, strides=2, activation='elu', padding='same'),
            layers.Conv2DTranspose(32, kernel_size=4, strides=2, activation='elu', padding='same'),
            layers.Conv2D(3, (4, 4), activation='sigmoid', padding='valid', strides=1)
        ])
    def call(self, x):
        # print("x_shape", x.shape)
        encoded = self.encoder(x)
        # print("encoded_shape", encoded.shape)
        decoded = self.decoder(encoded)
        # print("decoded_shape", decoded.shape)
        return decoded

# Setting of Model.
# strategy = tf.distribute.MirroredStrategy()
# print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# with strategy.scope():
model = ConvolutionalAutoencoder(config.dim)

optimizer = tf.keras.optimizers.Adam(config.learning_rate)
model.compile(optimizer=optimizer, loss=losses.MeanSquaredError())

# %%
# Fit model.
callbacks = [
    WandbCallback(),
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1)
]
model.fit(X_train, X_train, 
            epochs=config.epochs, 
            batch_size=config.batch_size, 
            shuffle=True,
            validation_data=(X_test, X_test),
            callbacks=callbacks)
run.finish()
# Out:
# Epoch 1/200
# 289/289 [==============================] - 13s 29ms/step - loss: 0.0327 - val_loss: 0.0041
# wandb: ERROR Can't save model, h5py returned error: Saving the model to HDF5 format requires the model to be a Functional model or a Sequential model. It does not work for subclassed models, because such models are defined via the body of a Python method, which isn't safely serializable. Consider saving to the Tensorflow SavedModel format (by setting save_format="tf") or using `save_weights`.
# Epoch 2/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 3/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 4/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 5/200
# 289/289 [==============================] - 7s 25ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 6/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 7/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 8/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 9/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 10/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 11/200
# 289/289 [==============================] - 7s 25ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 12/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 13/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 14/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 15/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 16/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0011 - val_loss: 0.0010
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 17/200
# 289/289 [==============================] - 7s 24ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 18/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.9676e-04 - val_loss: 0.0010
# Epoch 19/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.8657e-04 - val_loss: 0.0010
# Epoch 20/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.9012e-04 - val_loss: 9.9964e-04
# Epoch 21/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.9128e-04 - val_loss: 9.9665e-04
# Epoch 22/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.7948e-04 - val_loss: 9.9249e-04
# Epoch 23/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.7904e-04 - val_loss: 9.9022e-04
# Epoch 24/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.8003e-04 - val_loss: 9.8616e-04
# Epoch 25/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.6482e-04 - val_loss: 9.8143e-04
# Epoch 26/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.5359e-04 - val_loss: 9.7772e-04
# Epoch 27/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.4335e-04 - val_loss: 9.7392e-04
# Epoch 28/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.4026e-04 - val_loss: 9.7018e-04
# Epoch 29/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.3575e-04 - val_loss: 9.6618e-04
# Epoch 30/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.4568e-04 - val_loss: 9.6189e-04
# Epoch 31/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.3206e-04 - val_loss: 9.5810e-04
# Epoch 32/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.2958e-04 - val_loss: 9.5545e-04
# Epoch 33/200
# 289/289 [==============================] - 7s 25ms/step - loss: 9.1999e-04 - val_loss: 9.5183e-04
# Epoch 34/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.3115e-04 - val_loss: 9.4939e-04
# Epoch 35/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.1646e-04 - val_loss: 9.4556e-04
# Epoch 36/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.1101e-04 - val_loss: 9.4178e-04
# Epoch 37/200
# 289/289 [==============================] - 7s 24ms/step - loss: 9.1578e-04 - val_loss: 9.3917e-04
# Epoch 38/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.9241e-04 - val_loss: 9.3584e-04
# Epoch 39/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.9384e-04 - val_loss: 9.3192e-04
# Epoch 40/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.9466e-04 - val_loss: 9.2863e-04
# Epoch 41/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.7722e-04 - val_loss: 9.2782e-04
# Epoch 42/200
# 289/289 [==============================] - 7s 25ms/step - loss: 8.8182e-04 - val_loss: 9.2437e-04
# Epoch 43/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.8155e-04 - val_loss: 9.2092e-04
# Epoch 44/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.7276e-04 - val_loss: 9.1806e-04
# Epoch 45/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.7493e-04 - val_loss: 9.1602e-04
# Epoch 46/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.6694e-04 - val_loss: 9.1327e-04
# Epoch 47/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.6699e-04 - val_loss: 9.0978e-04
# Epoch 48/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.5253e-04 - val_loss: 9.0861e-04
# Epoch 49/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.6111e-04 - val_loss: 9.0562e-04
# Epoch 50/200
# 289/289 [==============================] - 7s 25ms/step - loss: 8.5754e-04 - val_loss: 9.0409e-04
# Epoch 51/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.5162e-04 - val_loss: 9.0110e-04
# Epoch 52/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.3540e-04 - val_loss: 9.0003e-04
# Epoch 53/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.3801e-04 - val_loss: 8.9597e-04
# Epoch 54/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.4342e-04 - val_loss: 8.9605e-04
# Epoch 55/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.4294e-04 - val_loss: 8.9314e-04
# Epoch 56/200
# 289/289 [==============================] - 7s 25ms/step - loss: 8.3599e-04 - val_loss: 8.9059e-04
# Epoch 57/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.2856e-04 - val_loss: 8.8820e-04
# Epoch 58/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.2152e-04 - val_loss: 8.8625e-04
# Epoch 59/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.2346e-04 - val_loss: 8.8633e-04
# Epoch 60/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.1043e-04 - val_loss: 8.8220e-04
# Epoch 61/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.1719e-04 - val_loss: 8.8216e-04
# Epoch 62/200
# 289/289 [==============================] - 7s 25ms/step - loss: 8.2050e-04 - val_loss: 8.8045e-04
# Epoch 63/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.1249e-04 - val_loss: 8.7721e-04
# Epoch 64/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.0793e-04 - val_loss: 8.7536e-04
# Epoch 65/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.9917e-04 - val_loss: 8.7446e-04
# Epoch 66/200
# 289/289 [==============================] - 7s 25ms/step - loss: 8.0376e-04 - val_loss: 8.7230e-04
# Epoch 67/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.0207e-04 - val_loss: 8.7071e-04
# Epoch 68/200
# 289/289 [==============================] - 7s 24ms/step - loss: 8.0105e-04 - val_loss: 8.6850e-04
# Epoch 69/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.9293e-04 - val_loss: 8.6740e-04
# Epoch 70/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.8786e-04 - val_loss: 8.6836e-04
# Epoch 71/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.8743e-04 - val_loss: 8.6418e-04
# Epoch 72/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.8712e-04 - val_loss: 8.6308e-04
# Epoch 73/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.8811e-04 - val_loss: 8.6169e-04
# Epoch 74/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.7903e-04 - val_loss: 8.5906e-04
# Epoch 75/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.8133e-04 - val_loss: 8.5819e-04
# Epoch 76/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.6993e-04 - val_loss: 8.5787e-04
# Epoch 77/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.7684e-04 - val_loss: 8.5609e-04
# Epoch 78/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.6853e-04 - val_loss: 8.5293e-04
# Epoch 79/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.7278e-04 - val_loss: 8.5311e-04
# Epoch 80/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.7346e-04 - val_loss: 8.5154e-04
# Epoch 81/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.5665e-04 - val_loss: 8.5038e-04
# Epoch 82/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.6120e-04 - val_loss: 8.4891e-04
# Epoch 83/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.6122e-04 - val_loss: 8.4958e-04
# Epoch 84/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.6490e-04 - val_loss: 8.4643e-04
# Epoch 85/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.5939e-04 - val_loss: 8.4589e-04
# Epoch 86/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.5361e-04 - val_loss: 8.4488e-04
# Epoch 87/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.5208e-04 - val_loss: 8.4430e-04
# Epoch 88/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.4540e-04 - val_loss: 8.4339e-04
# Epoch 89/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.4618e-04 - val_loss: 8.4179e-04
# Epoch 90/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.4266e-04 - val_loss: 8.4115e-04
# Epoch 91/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.3787e-04 - val_loss: 8.3872e-04
# Epoch 92/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.3333e-04 - val_loss: 8.3758e-04
# Epoch 93/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.4144e-04 - val_loss: 8.3740e-04
# Epoch 94/200
# 289/289 [==============================] - 7s 25ms/step - loss: 7.2808e-04 - val_loss: 8.3683e-04
# Epoch 95/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.3664e-04 - val_loss: 8.3470e-04
# Epoch 96/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2118e-04 - val_loss: 8.3648e-04
# Epoch 97/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2382e-04 - val_loss: 8.3463e-04
# Epoch 98/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2250e-04 - val_loss: 8.3199e-04
# Epoch 99/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2783e-04 - val_loss: 8.3307e-04
# Epoch 100/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2271e-04 - val_loss: 8.3288e-04
# Epoch 101/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2149e-04 - val_loss: 8.3036e-04
# Epoch 102/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.2067e-04 - val_loss: 8.3004e-04
# Epoch 103/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.1586e-04 - val_loss: 8.3030e-04
# Epoch 104/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.1458e-04 - val_loss: 8.2858e-04
# Epoch 105/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0988e-04 - val_loss: 8.2754e-04
# Epoch 106/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0972e-04 - val_loss: 8.2709e-04
# Epoch 107/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0312e-04 - val_loss: 8.2693e-04
# Epoch 108/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0736e-04 - val_loss: 8.2719e-04
# Epoch 109/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0796e-04 - val_loss: 8.2500e-04
# Epoch 110/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0264e-04 - val_loss: 8.2526e-04
# Epoch 111/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.9473e-04 - val_loss: 8.2493e-04
# Epoch 112/200
# 289/289 [==============================] - 7s 24ms/step - loss: 7.0424e-04 - val_loss: 8.2334e-04
# Epoch 113/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.9972e-04 - val_loss: 8.2342e-04
# Epoch 114/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.9842e-04 - val_loss: 8.2202e-04
# Epoch 115/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.8182e-04 - val_loss: 8.2132e-04
# Epoch 116/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.8844e-04 - val_loss: 8.2106e-04
# Epoch 117/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.9775e-04 - val_loss: 8.2154e-04
# Epoch 118/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.9270e-04 - val_loss: 8.2063e-04
# Epoch 119/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.8606e-04 - val_loss: 8.1949e-04
# Epoch 120/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.9292e-04 - val_loss: 8.1968e-04
# Epoch 121/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.8227e-04 - val_loss: 8.1876e-04
# Epoch 122/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.8184e-04 - val_loss: 8.1931e-04
# Epoch 123/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.7792e-04 - val_loss: 8.1786e-04
# Epoch 124/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.7649e-04 - val_loss: 8.1754e-04
# Epoch 125/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.8097e-04 - val_loss: 8.1597e-04
# Epoch 126/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.7932e-04 - val_loss: 8.1703e-04
# Epoch 127/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.7253e-04 - val_loss: 8.1727e-04
# Epoch 128/200
# 289/289 [==============================] - 7s 25ms/step - loss: 6.8235e-04 - val_loss: 8.1789e-04
# Epoch 129/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6410e-04 - val_loss: 8.1633e-04
# Epoch 130/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6459e-04 - val_loss: 8.1672e-04
# Epoch 131/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6131e-04 - val_loss: 8.1542e-04
# Epoch 132/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6185e-04 - val_loss: 8.1531e-04
# Epoch 133/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5653e-04 - val_loss: 8.1521e-04
# Epoch 134/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6077e-04 - val_loss: 8.1419e-04
# Epoch 135/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5627e-04 - val_loss: 8.1356e-04
# Epoch 136/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6646e-04 - val_loss: 8.1390e-04
# Epoch 137/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5719e-04 - val_loss: 8.1409e-04
# Epoch 138/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5609e-04 - val_loss: 8.1363e-04
# Epoch 139/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5161e-04 - val_loss: 8.1225e-04
# Epoch 140/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4837e-04 - val_loss: 8.1225e-04
# Epoch 141/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4837e-04 - val_loss: 8.1380e-04
# Epoch 142/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.6156e-04 - val_loss: 8.1424e-04
# Epoch 143/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4923e-04 - val_loss: 8.1185e-04
# Epoch 144/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5001e-04 - val_loss: 8.1116e-04
# Epoch 145/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.5465e-04 - val_loss: 8.1272e-04
# Epoch 146/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4777e-04 - val_loss: 8.1123e-04
# Epoch 147/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4519e-04 - val_loss: 8.1218e-04
# Epoch 148/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4328e-04 - val_loss: 8.1153e-04
# Epoch 149/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.4612e-04 - val_loss: 8.1304e-04
# Epoch 150/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3888e-04 - val_loss: 8.1282e-04
# Epoch 151/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3623e-04 - val_loss: 8.1285e-04
# Epoch 152/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3772e-04 - val_loss: 8.1156e-04
# Epoch 153/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3787e-04 - val_loss: 8.1111e-04
# Epoch 154/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3987e-04 - val_loss: 8.0968e-04
# Epoch 155/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3249e-04 - val_loss: 8.1214e-04
# Epoch 156/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3275e-04 - val_loss: 8.0921e-04
# Epoch 157/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3003e-04 - val_loss: 8.1287e-04
# Epoch 158/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3121e-04 - val_loss: 8.1082e-04
# Epoch 159/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.2743e-04 - val_loss: 8.1150e-04
# Epoch 160/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.3160e-04 - val_loss: 8.1161e-04
# Epoch 161/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.2831e-04 - val_loss: 8.1006e-04
# Epoch 162/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.2735e-04 - val_loss: 8.1119e-04
# Epoch 163/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.2023e-04 - val_loss: 8.1029e-04
# Epoch 164/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.2020e-04 - val_loss: 8.1228e-04
# Epoch 165/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.1911e-04 - val_loss: 8.1042e-04
# Epoch 166/200
# 289/289 [==============================] - 7s 24ms/step - loss: 6.2586e-04 - val_loss: 8.1373e-04
# Epoch 00166: early stopping
# <br/>Waiting for W&B process to finish, PID 442069<br/>Program ended successfully.
# Find user logs for this run at: <code>/root/share/tecnets-pytorch/scripts/wandb/run-20210427_141210-hw7h92f9/logs/debug.log</code>
# Find internal logs for this run at: <code>/root/share/tecnets-pytorch/scripts/wandb/run-20210427_141210-hw7h92f9/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>165</td></tr><tr><td>loss</td><td>0.00062</td></tr><tr><td>val_loss</td><td>0.00081</td></tr><tr><td>_runtime</td><td>1226</td></tr><tr><td>_timestamp</td><td>1619533956</td></tr><tr><td>_step</td><td>165</td></tr><tr><td>best_val_loss</td><td>0.00081</td></tr><tr><td>best_epoch</td><td>155</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ethereal-breeze-6</strong>: <a href="https://wandb.ai/shogi880/Convautoencoder-pretrain_128/runs/hw7h92f9" target="_blank">https://wandb.ai/shogi880/Convautoencoder-pretrain_128/runs/hw7h92f9</a><br/>

# %%
# 可視化
k = 20
input_data = X_test
# input_data = X_train

encoded_imgs = model.encoder(input_data[k:k+20]).numpy()
decoded_imgs = model.decoder(encoded_imgs).numpy()

import matplotlib.pyplot as plt
n = 10
plt.figure(figsize=(25, 10))
for i in range(n):
    # display original
    ax = plt.subplot(4, n, i + 1)
    plt.imshow(input_data[k+i])
    plt.title("X_test : original")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(4, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    plt.title("reconstructed")
    plt.gray()
    ax.get_xaxis().set_visible(False)

        # display original
    ax = plt.subplot(4, n, i + 1 + 2 * n)
    plt.imshow(input_data[k + i + n])
    plt.title("X_test : original")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstruction
    ax = plt.subplot(4, n, i + 1 + 3 * n)
    plt.imshow(decoded_imgs[i + n])
    plt.title("reconstructed")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    
ax.get_yaxis().set_visible(False)
plt.show()
